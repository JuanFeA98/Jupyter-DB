# %% [markdown]
# ### Cargamos nuestras librerias

# %%
import os

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import mysql.connector

# %% [markdown]
# ### Conexión con la base de datos

# %%
con = mysql.connector.connect(
    host="database-test.c9nlbydrtdtu.us-east-2.rds.amazonaws.com",
    user="admin",
    passwd="1014296783",
    database="test"
)

# %% [markdown]
# ### Consulta a la base de datos

# %%
df = pd.read_sql('select * from churn where myunknowncolumn = 1', con=con)

# %%
df
# Out:
#    MyUnknownColumn gender  SeniorCitizen Partner Dependents  tenure  \
# 0                1   Male              0      No         No      34
#
#   PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0          Yes            No             DSL            Yes  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 0              Yes          No          No              No  One year
#
#   PaperlessBilling PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0               No  Mailed check          56.95        1889.5     No
#
# [1 rows x 21 columns]
